# %%
import pandas as pd
from transformers import pipeline

# %%
data = pd.read_csv('/kaggle/input/llms-you-cant-please-them-all/test.csv')

# %%
data.head()
# Out:
#         id  \
# 0  1097671
# 1  1726150
# 2  3211968
#
#                                                                                            topic
# 0           Compare and contrast the importance of self-reliance and adaptability in healthcare.
# 1  Evaluate the effectiveness of management consulting in addressing conflicts within marketing.
# 2                Discuss the role of self-reliance in achieving success in software engineering.

# %%
pd.set_option('display.max_colwidth',None)

# %%
import pandas as pd
from transformers import pipeline

file_path = '/kaggle/input/llms-you-cant-please-them-all/test.csv'
sample_submission_path = '/kaggle/input/llms-you-cant-please-them-all/sample_submission.csv'

df = pd.read_csv(file_path)
sample_sub = pd.read_csv(sample_submission_path)

topics = df['topic'].head(3)

llm = pipeline("text-generation", model="gpt2")

outputs = []
for topic in topics:
    output = llm(topic, max_length=100, num_return_sequences=1)
    outputs.append(output[0]['generated_text'])

generated_outputs = []
for i, output in enumerate(outputs):
    generated_outputs.append({
        'Topic': topics.iloc[i],
        'Generated Output': output
    })

print(generated_outputs)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'Topic': 'Compare and contrast the importance of self-reliance and adaptability in healthcare.', 'Generated Output': "Compare and contrast the importance of self-reliance and adaptability in healthcare.\n\n5 The Self-Reliance of Healthcare Workers.\n\nThe relationship is obvious from the data shown above:\n\nThe share of self-reliance (as opposed to a worker's ability to use the system) increased on average by 50% in every age group in the United States compared to the overall population (Figure 5). The largest gains are found amongst children and women aged 12 to 17 years in"}, {'Topic': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.', 'Generated Output': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.\n\n• Create a comprehensive and effective policy for managing conflicts within retail business (MVD) in New York.\n\n• Create a nationwide approach to resolving conflicts within consumer brands.\n\n• Create programs to educate consumers about the benefits of the business, including the potential impact of this shift on business competitiveness in the business and the management landscape.\n\nAdvisory staff to help with any matters that may be pertinent:\n'}, {'Topic': 'Discuss the role of self-reliance in achieving success in software engineering.', 'Generated Output': 'Discuss the role of self-reliance in achieving success in software engineering. This article focuses primarily on self-reliance, but can be taken to be an important part of learning how to be a good software engineer in the next three years.\n\nSelf-reliance is an important factor in creating and maintaining a team at a high level. In fact, a good team member should be self-reliant even if he fails to make the most of his opportunities. This often occurs due to'}]

# %%
generated_outputs
# Out:
# [{'Topic': 'Compare and contrast the importance of self-reliance and adaptability in healthcare.',
#   'Generated Output': "Compare and contrast the importance of self-reliance and adaptability in healthcare.\n\n5 The Self-Reliance of Healthcare Workers.\n\nThe relationship is obvious from the data shown above:\n\nThe share of self-reliance (as opposed to a worker's ability to use the system) increased on average by 50% in every age group in the United States compared to the overall population (Figure 5). The largest gains are found amongst children and women aged 12 to 17 years in"},
#  {'Topic': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.',
#   'Generated Output': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.\n\n• Create a comprehensive and effective policy for managing conflicts within retail business (MVD) in New York.\n\n• Create a nationwide approach to resolving conflicts within consumer brands.\n\n• Create programs to educate consumers about the benefits of the business, including the potential impact of this shift on business competitiveness in the business and the management landscape.\n\nAdvisory staff to help with any matters that may be pertinent:\n'},
#  {'Topic': 'Discuss the role of self-reliance in achieving success in software engineering.',
#   'Generated Output': 'Discuss the role of self-reliance in achieving success in software engineering. This article focuses primarily on self-reliance, but can be taken to be an important part of learning how to be a good software engineer in the next three years.\n\nSelf-reliance is an important factor in creating and maintaining a team at a high level. In fact, a good team member should be self-reliant even if he fails to make the most of his opportunities. This often occurs due to'}]

# %%
sample = pd.read_csv('/kaggle/input/llms-you-cant-please-them-all/sample_submission.csv')

# %%
sample['essay'] = generated_outputs

# %%
sample
# Out:
#         id  \
# 0  1097671
# 1  1726150
# 2  3211968
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 essay
# 0                                                                                                 {'Topic': 'Compare and contrast the importance of self-reliance and adaptability in healthcare.', 'Generated Output': 'Compare and contrast the importance of self-reliance and adaptability in healthcare.
#
# 5 The Self-Reliance of Healthcare Workers.
#
# The relationship is obvious from the data shown above:
#
# The share of self-reliance (as opposed to a worker's ability to use the system) increased on average by 50% in every age group in the United States compared to the overall population (Figure 5). The largest gains are found amongst children and women aged 12 to 17 years in'}
# 1  {'Topic': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.', 'Generated Output': 'Evaluate the effectiveness of management consulting in addressing conflicts within marketing.
#
# • Create a comprehensive and effective policy for managing conflicts within retail business (MVD) in New York.
#
# • Create a nationwide approach to resolving conflicts within consumer brands.
#
# • Create programs to educate consumers about the benefits of the business, including the potential impact of this shift on business competitiveness in the business and the management landscape.
#
# Advisory staff to help with any matters that may be pertinent:
# '}
# 2                                                                                                 {'Topic': 'Discuss the role of self-reliance in achieving success in software engineering.', 'Generated Output': 'Discuss the role of self-reliance in achieving success in software engineering. This article focuses primarily on self-reliance, but can be taken to be an important part of learning how to be a good software engineer in the next three years.
#
# Self-reliance is an important factor in creating and maintaining a team at a high level. In fact, a good team member should be self-reliant even if he fails to make the most of his opportunities. This often occurs due to'}

# %%
sample.to_csv('submission.csv',index = False)
